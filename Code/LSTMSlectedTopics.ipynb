# %% [markdown]
# # Import DATA

# %%
import pandas as pd
import numpy as np
data =pd.read_csv('aug_train_preprocessed.csv')

data.head()
# Out:
#    enrollee_id  city  city_development_index  gender  relevent_experience  \
# 0         5018     5                      85       1                    0
# 1        16986    77                      48       1                    1
# 2         6499    64                      14       3                    1
# 3        19067    14                      52       3                    1
# 4          358    50                      45       1                    0
#
#    enrolled_university  education_level  major_discipline  experience  \
# 0                    3                0                 5          21
# 1                    3                0                 5           6
# 2                    0                0                 5          15
# 3                    2                0                 1          20
# 4                    3                2                 5          21
#
#    company_size  company_type  last_new_job  training_hours  target
# 0             8             6             0              35       1
# 1             4             5             4              46       0
# 2             8             6             6              82       0
# 3             8             5             6              51       1
# 4             4             1             3               7       0

# %%
data.shape
# Out:
# (19158, 14)

# %%
df=pd.DataFrame(data)

# %%
data.dtypes
# Out:
# enrollee_id               int64
# city                      int64
# city_development_index    int64
# gender                    int64
# relevent_experience       int64
# enrolled_university       int64
# education_level           int64
# major_discipline          int64
# experience                int64
# company_size              int64
# company_type              int64
# last_new_job              int64
# training_hours            int64
# target                    int64
# dtype: object

# %%
# studying null values
data.isnull().sum( )
# Out:
# enrollee_id               0
# city                      0
# city_development_index    0
# gender                    0
# relevent_experience       0
# enrolled_university       0
# education_level           0
# major_discipline          0
# experience                0
# company_size              0
# company_type              0
# last_new_job              0
# training_hours            0
# target                    0
# dtype: int64

# %%
data=data.set_index('enrollee_id')
data.head(10)
# Out:
#              city  city_development_index  gender  relevent_experience  \
# enrollee_id
# 5018            5                      85       1                    0
# 16986          77                      48       1                    1
# 6499           64                      14       3                    1
# 19067          14                      52       3                    1
# 358            50                      45       1                    0
# 12304          57                      43       3                    0
# 16451          49                      85       1                    0
# 218            83                      41       1                    0
# 15481           5                      85       1                    0
# 375             5                      85       3                    0
#
#              enrolled_university  education_level  major_discipline  \
# enrollee_id
# 5018                           3                0                 5
# 16986                          3                0                 5
# 6499                           0                0                 5
# 19067                          2                0                 1
# 358                            3                2                 5
# 12304                          1                0                 5
# 16451                          3                1                 6
# 218                            3                0                 5
# 15481                          3                0                 5
# 375                            3                0                 5
#
#              experience  company_size  company_type  last_new_job  \
# enrollee_id
# 5018                 21             8             6             0
# 16986                 6             4             5             4
# 6499                 15             8             6             6
# 19067                20             8             5             6
# 358                  21             4             1             3
# 12304                 2             8             6             0
# 16451                15             4             1             0
# 218                   4             7             5             4
# 15481                17             4             5             0
# 375                   8             3             5             4
#
#              training_hours  target
# enrollee_id
# 5018                     35       1
# 16986                    46       0
# 6499                     82       0
# 19067                    51       1
# 358                       7       0
# 12304                    23       1
# 16451                    23       0
# 218                      17       1
# 15481                    45       1
# 375                     120       0

# %%
data.head(10)
# Out:
#              city  city_development_index  gender  relevent_experience  \
# enrollee_id
# 5018            5                      85       1                    0
# 16986          77                      48       1                    1
# 6499           64                      14       3                    1
# 19067          14                      52       3                    1
# 358            50                      45       1                    0
# 12304          57                      43       3                    0
# 16451          49                      85       1                    0
# 218            83                      41       1                    0
# 15481           5                      85       1                    0
# 375             5                      85       3                    0
#
#              enrolled_university  education_level  major_discipline  \
# enrollee_id
# 5018                           3                0                 5
# 16986                          3                0                 5
# 6499                           0                0                 5
# 19067                          2                0                 1
# 358                            3                2                 5
# 12304                          1                0                 5
# 16451                          3                1                 6
# 218                            3                0                 5
# 15481                          3                0                 5
# 375                            3                0                 5
#
#              experience  company_size  company_type  last_new_job  \
# enrollee_id
# 5018                 21             8             6             0
# 16986                 6             4             5             4
# 6499                 15             8             6             6
# 19067                20             8             5             6
# 358                  21             4             1             3
# 12304                 2             8             6             0
# 16451                15             4             1             0
# 218                   4             7             5             4
# 15481                17             4             5             0
# 375                   8             3             5             4
#
#              training_hours  target
# enrollee_id
# 5018                     35       1
# 16986                    46       0
# 6499                     82       0
# 19067                    51       1
# 358                       7       0
# 12304                    23       1
# 16451                    23       0
# 218                      17       1
# 15481                    45       1
# 375                     120       0

# %%
x=data.drop(columns='target')
x
# Out:
#              city  city_development_index  gender  relevent_experience  \
# enrollee_id
# 5018            5                      85       1                    0
# 16986          77                      48       1                    1
# 6499           64                      14       3                    1
# 19067          14                      52       3                    1
# 358            50                      45       1                    0
# ...           ...                     ...     ...                  ...
# 4117           55                      71       1                    1
# 17981           5                      85       1                    0
# 14021           5                      85       1                    0
# 3185           94                      56       1                    0
# 13567          95                      67       3                    1
#
#              enrolled_university  education_level  major_discipline  \
# enrollee_id
# 5018                           3                0                 5
# 16986                          3                0                 5
# 6499                           0                0                 5
# 19067                          2                0                 1
# 358                            3                2                 5
# ...                          ...              ...               ...
# 4117                           3                0                 2
# 17981                          3                0                 5
# 14021                          3                0                 5
# 3185                           3                1                 6
# 13567                          3                4                 6
#
#              experience  company_size  company_type  last_new_job  \
# enrollee_id
# 5018                 21             8             6             0
# 16986                 6             4             5             4
# 6499                 15             8             6             6
# 19067                20             8             5             6
# 358                  21             4             1             3
# ...                 ...           ...           ...           ...
# 4117                  5             8             6             0
# 17981                 5             8             6             3
# 14021                21             4             5             3
# 3185                 20             5             5             1
# 13567                11             8             6             0
#
#              training_hours
# enrollee_id
# 5018                     35
# 16986                    46
# 6499                     82
# 19067                    51
# 358                       7
# ...                     ...
# 4117                     41
# 17981                    51
# 14021                    43
# 3185                     95
# 13567                   124
#
# [19158 rows x 12 columns]

# %%
y=data['target']
y
# Out:
# enrollee_id
# 5018     1
# 16986    0
# 6499     0
# 19067    1
# 358      0
#         ..
# 4117     1
# 17981    1
# 14021    0
# 3185     0
# 13567    0
# Name: target, Length: 19158, dtype: int64

# %% [markdown]
# ## DATA visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(data)

# %%
sns.pairplot(data, hue='target')

# %% [markdown]
# ## Normaliznig data

# %%
# normaliznig data
from sklearn.preprocessing import StandardScaler

x = StandardScaler().fit_transform(x)

# %%
x
# Out:
# array([[-1.10520322,  0.75589002, -0.45309951, ...,  0.79735656,
#         -0.90426948, -0.51266315],
#        [ 0.9250771 , -0.5100811 , -0.45309951, ...,  0.12727905,
#          0.91825376, -0.30004804],
#        [ 0.55849871, -1.67340591,  1.72546253, ...,  0.79735656,
#          1.82951538,  0.39578325],
#        ...,
#        [-1.10520322,  0.75589002, -0.45309951, ...,  0.12727905,
#          0.46262295, -0.35803398],
#        [ 1.40444885, -0.23635762, -0.45309951, ...,  0.12727905,
#         -0.44863867,  0.64705566],
#        [ 1.43264719,  0.14001218,  1.72546253, ...,  0.79735656,
#         -0.90426948,  1.20758643]])

# %%
x = StandardScaler().fit_transform(x)

# %%
x
# Out:
# array([[-1.10520322,  0.75589002, -0.45309951, ...,  0.79735656,
#         -0.90426948, -0.51266315],
#        [ 0.9250771 , -0.5100811 , -0.45309951, ...,  0.12727905,
#          0.91825376, -0.30004804],
#        [ 0.55849871, -1.67340591,  1.72546253, ...,  0.79735656,
#          1.82951538,  0.39578325],
#        ...,
#        [-1.10520322,  0.75589002, -0.45309951, ...,  0.12727905,
#          0.46262295, -0.35803398],
#        [ 1.40444885, -0.23635762, -0.45309951, ...,  0.12727905,
#         -0.44863867,  0.64705566],
#        [ 1.43264719,  0.14001218,  1.72546253, ...,  0.79735656,
#         -0.90426948,  1.20758643]])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import plot_confusion_matrix, classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train)
y_pred=model.predict(X_test)
print(classification_report(y_test, model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.86      2880
#            1       0.56      0.46      0.51       952
#
#     accuracy                           0.78      3832
#    macro avg       0.70      0.67      0.68      3832
# weighted avg       0.76      0.78      0.77      3832

# %%
cf_matrix = confusion_matrix(y_test, y_pred)

# %%
print(cf_matrix)
# Out:
# [[2532  348]
#  [ 510  442]]

# %%
sns.heatmap(cf_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cf_matrix/np.sum(cf_matrix), annot=True, 
            fmt='.2%', cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
import numpy
from tensorflow import keras 
from tensorflow.keras.datasets import imdb

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, RepeatVector, TimeDistributed
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing import sequence
# fix random seed for reproducibility
numpy.random.seed(7)

# %%
def prepare_datasets(test_size, validation_size):

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    return X_train, X_validation, X_test, y_train, y_validation, y_test

# %%
def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs
        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()

# %%
x.shape
x
# Out:
# array([[[-1.10520322],
#         [ 0.75589002],
#         [-0.45309951],
#         ...,
#         [ 0.79735656],
#         [-0.90426948],
#         [-0.51266315]],
#
#        [[ 0.9250771 ],
#         [-0.5100811 ],
#         [-0.45309951],
#         ...,
#         [ 0.12727905],
#         [ 0.91825376],
#         [-0.30004804]],
#
#        [[ 0.55849871],
#         [-1.67340591],
#         [ 1.72546253],
#         ...,
#         [ 0.79735656],
#         [ 1.82951538],
#         [ 0.39578325]],
#
#        ...,
#
#        [[-1.10520322],
#         [ 0.75589002],
#         [-0.45309951],
#         ...,
#         [ 0.12727905],
#         [ 0.46262295],
#         [-0.35803398]],
#
#        [[ 1.40444885],
#         [-0.23635762],
#         [-0.45309951],
#         ...,
#         [ 0.12727905],
#         [-0.44863867],
#         [ 0.64705566]],
#
#        [[ 1.43264719],
#         [ 0.14001218],
#         [ 1.72546253],
#         ...,
#         [ 0.79735656],
#         [-0.90426948],
#         [ 1.20758643]]])

# %%
x = np.reshape(x,(19158,12,1))

# %%
x.shape
# Out:
# (19158, 12, 1)

# %%
def build_model(inputshape):
    model = Sequential()

    model.add(keras.layers.LSTM(64,input_shape=inputshape, return_sequences=True))
    
    model.add(keras.layers.LSTM(64))
    model.add(keras.layers.Dense(64,activation='relu'))
    model.add(keras.layers.Dropout(rate=0.3))
    
   
    model.add(keras.layers.Dense(2,activation='softmax'))
   
    model.summary()
    return model

if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2]) # 130, 13
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=30)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 12, 64)            16896
#
#  lstm_3 (LSTM)               (None, 64)                33024
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 54,210
# Trainable params: 54,210
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 12, 64)            16896
#
#  lstm_3 (LSTM)               (None, 64)                33024
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 54,210
# Trainable params: 54,210
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 360/360 [==============================] - 7s 10ms/step - loss: 0.5883 - accuracy: 0.7419 - val_loss: 0.5402 - val_accuracy: 0.7571
# Epoch 2/30
# 360/360 [==============================] - 3s 8ms/step - loss: 0.5477 - accuracy: 0.7494 - val_loss: 0.5327 - val_accuracy: 0.7564
# Epoch 3/30
# 360/360 [==============================] - 3s 8ms/step - loss: 0.5377 - accuracy: 0.7514 - val_loss: 0.5168 - val_accuracy: 0.7630
# Epoch 4/30
# 360/360 [==============================] - 3s 8ms/step - loss: 0.5237 - accuracy: 0.7525 - val_loss: 0.5030 - val_accuracy: 0.7617
# Epoch 5/30
# 360/360 [==============================] - 3s 8ms/step - loss: 0.5185 - accuracy: 0.7551 - val_loss: 0.4996 - val_accuracy: 0.7641
# Epoch 6/30
# 360/360 [==============================] - 3s 9ms/step - loss: 0.5151 - accuracy: 0.7565 - val_loss: 0.4965 - val_accuracy: 0.7648
# Epoch 7/30
# 360/360 [==============================] - 3s 9ms/step - loss: 0.5126 - accuracy: 0.7562 - val_loss: 0.4953 - val_accuracy: 0.7641
# Epoch 8/30
# 360/360 [==============================] - 3s 9ms/step - loss: 0.5126 - accuracy: 0.7575 - val_loss: 0.4961 - val_accuracy: 0.7627
# Epoch 9/30
# 360/360 [==============================] - 4s 10ms/step - loss: 0.5118 - accuracy: 0.7558 - val_loss: 0.4947 - val_accuracy: 0.7644
# Epoch 10/30
# 360/360 [==============================] - 3s 9ms/step - loss: 0.5112 - accuracy: 0.7557 - val_loss: 0.4929 - val_accuracy: 0.7641
# Epoch 11/30
# 360/360 [==============================] - 3s 9ms/step - loss: 0.5087 - accuracy: 0.7586 - val_loss: 0.4940 - val_accuracy: 0.7651
# Epoch 12/30
# 360/360 [==============================] - 3s 9ms/step - loss: 0.5088 - accuracy: 0.7576 - val_loss: 0.4967 - val_accuracy: 0.7637
# Epoch 13/30
# 360/360 [==============================] - 4s 11ms/step - loss: 0.5061 - accuracy: 0.7568 - val_loss: 0.4954 - val_accuracy: 0.7637
# Epoch 14/30
# 360/360 [==============================] - 3s 9ms/step - loss: 0.5065 - accuracy: 0.7553 - val_loss: 0.4929 - val_accuracy: 0.7634
# Epoch 15/30
# 360/360 [==============================] - 3s 9ms/step - loss: 0.5062 - accuracy: 0.7571 - val_loss: 0.4899 - val_accuracy: 0.7669
# Epoch 16/30
# 360/360 [==============================] - 3s 9ms/step - loss: 0.5067 - accuracy: 0.7581 - val_loss: 0.4910 - val_accuracy: 0.7634
# Epoch 17/30
# 360/360 [==============================] - 4s 11ms/step - loss: 0.5043 - accuracy: 0.7575 - val_loss: 0.4914 - val_accuracy: 0.7641
# Epoch 18/30
# 360/360 [==============================] - 4s 10ms/step - loss: 0.5046 - accuracy: 0.7581 - val_loss: 0.4899 - val_accuracy: 0.7676
# Epoch 19/30
# 360/360 [==============================] - 4s 10ms/step - loss: 0.5034 - accuracy: 0.7591 - val_loss: 0.4892 - val_accuracy: 0.7644
# Epoch 20/30
# 360/360 [==============================] - 3s 9ms/step - loss: 0.5042 - accuracy: 0.7562 - val_loss: 0.4892 - val_accuracy: 0.7665
# Epoch 21/30
# 360/360 [==============================] - 3s 8ms/step - loss: 0.5033 - accuracy: 0.7567 - val_loss: 0.4894 - val_accuracy: 0.7662
# Epoch 22/30
# 360/360 [==============================] - 3s 9ms/step - loss: 0.5033 - accuracy: 0.7568 - val_loss: 0.4882 - val_accuracy: 0.7665
# Epoch 23/30
# 360/360 [==============================] - 3s 9ms/step - loss: 0.5031 - accuracy: 0.7602 - val_loss: 0.4878 - val_accuracy: 0.7662
# Epoch 24/30
# 360/360 [==============================] - 3s 9ms/step - loss: 0.5017 - accuracy: 0.7582 - val_loss: 0.4884 - val_accuracy: 0.7634
# Epoch 25/30
# 360/360 [==============================] - 3s 9ms/step - loss: 0.5027 - accuracy: 0.7560 - val_loss: 0.4877 - val_accuracy: 0.7620
# Epoch 26/30
# 360/360 [==============================] - 4s 10ms/step - loss: 0.5024 - accuracy: 0.7581 - val_loss: 0.4871 - val_accuracy: 0.7627
# Epoch 27/30
# 360/360 [==============================] - 4s 10ms/step - loss: 0.5000 - accuracy: 0.7572 - val_loss: 0.4916 - val_accuracy: 0.7651
# Epoch 28/30
# 360/360 [==============================] - 3s 9ms/step - loss: 0.5010 - accuracy: 0.7563 - val_loss: 0.4869 - val_accuracy: 0.7672
# Epoch 29/30
# 360/360 [==============================] - 3s 10ms/step - loss: 0.5009 - accuracy: 0.7569 - val_loss: 0.4874 - val_accuracy: 0.7644
# Epoch 30/30
# 360/360 [==============================] - 4s 10ms/step - loss: 0.5009 - accuracy: 0.7551 - val_loss: 0.4863 - val_accuracy: 0.7655
# 150/150 - 0s - loss: 0.4988 - accuracy: 0.7551 - 404ms/epoch - 3ms/step
#
# Test accuracy: 0.7551147937774658

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([[0.5417826 , 0.45821735],
#        [0.8130065 , 0.1869934 ],
#        [0.7614151 , 0.23858482],
#        ...,
#        [0.85847694, 0.14152305],
#        [0.43802568, 0.56197435],
#        [0.44098562, 0.5590144 ]], dtype=float32)

# %%
rounded_predictions=np.argmax(y_pred,axis=-1)

# %%
rounded_predictions
# Out:
# array([0, 0, 0, ..., 0, 1, 1])

# %%
cf_matrix = confusion_matrix(y_test, rounded_predictions)

# %%
sns.heatmap(cf_matrix/np.sum(cf_matrix), annot=True, 
            fmt='.2%', cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
# Out:
# <AxesSubplot:>
